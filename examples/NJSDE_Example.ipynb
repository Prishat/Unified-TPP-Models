# %%
import sys
sys.path.append('local_modules') # For using module in colab after cloning it

# %%
import random
import numpy as np

# %%
# Required Dependency for NJSDE
# !pip install git+https://github.com/000Justin000/torchdiffeq.git@jj585
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/000Justin000/torchdiffeq.git@jj585
#   Cloning https://github.com/000Justin000/torchdiffeq.git (to revision jj585) to /tmp/pip-req-build-hgpagxng
#   Running command git clone --filter=blob:none --quiet https://github.com/000Justin000/torchdiffeq.git /tmp/pip-req-build-hgpagxng
#   Running command git checkout -b jj585 --track origin/jj585
#   Switched to a new branch 'jj585'
#   Branch 'jj585' set up to track remote branch 'jj585' from 'origin'.
#   Resolved https://github.com/000Justin000/torchdiffeq.git to commit 66d853a05b498d8180e37cff16117b3bf3c91e64
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq==0.0.1) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->torchdiffeq==0.0.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.1->torchdiffeq==0.0.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.1->torchdiffeq==0.0.1) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.1->torchdiffeq==0.0.1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->torchdiffeq==0.0.1) (1.3.0)

# %%
# !git clone https://github.com/Prishat/Unified-TPP-Models.git module
# Out:
# fatal: destination path 'module' already exists and is not an empty directory.

# %% [markdown]
# # StackOverflow Dataset

# %%
from module.datasets import stackOverflow

# %%
data = stackOverflow({}, './')

# %%
len(data.ts), len(data.ts[0]), len(data.ts[0][0]), data.ts[0][0], data.tspan
# Out:
# (6633, 55, 2, (0.32084356712963846, 3), (0.0, 24.366497789351847))

# %%
from module.config import njsde_params
from module.models import njsde

# %%
njsde_params['niters'] = 2
njsde_params
# Out:
# {'niters': 2,
#  'jump_type': 'read',
#  'batch_size': 1,
#  'nsave': 10,
#  'fold': 0,
#  'num_types': 22,
#  'restart': False,
#  'evnt_align': False,
#  'seed0': False,
#  'debug': False}

# %%
model = njsde(njsde_params)

# %%
# Time for each epoch = 22s
# Use the first 6000 data points for training, validation and testing
model.train(data.ts[:6000], data.tspan)
# Out:
# iter: 0, current loss:   409.8182, running ave loss:   409.8182, type error: tensor([0.9899])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-83d06724809f> in <cell line: 3>()
#       1 # Time for each epoch = 22s
#       2 # Use the first 6000 data points for training, validation and testing
# ----> 3 model.train(data.ts[:6000], data.tspan)
#
# /content/module/models.py in train(self, ts, tspan)
#     145
#     146                 # forward pass
# --> 147                 tsave, trace, lmbda, gtid, tsne, loss, mete = forward_pass(self.func,
#     148                                                                            torch.cat((self.c0, self.h0), dim=-1), tspan,
#     149                                                                            dt,
#
# /content/module/utils.py in forward_pass(func, z0, tspan, dt, batch, evnt_align, gs_info, type_forecast, predict_first, rtol, atol, scale)
#     487
#     488     # forward pass
# --> 489     trace = odeint(func, z0.repeat(len(batch), 1), tsave, method='jump_adams', rtol=rtol, atol=atol)
#     490     params = func.L(trace)
#     491     lmbda = params[..., :func.dim_N]
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in odeint_adjoint(func, y0, t, rtol, atol, method, options)
#     210
#     211     flat_params = _flatten(func.parameters())
# --> 212     ys = OdeintAdjointMethod.apply(*y0, func, t, flat_params, rtol, atol, method, options)
#     213
#     214     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     504             # See NOTE: [functorch vjp and autograd interaction]
#     505             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     507
#     508         if cls.setup_context == _SingleLevelFunction.setup_context:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in forward(ctx, *args)
#      16
#      17         with torch.no_grad():
# ---> 18             ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options)
#      19         ctx.save_for_backward(t, flat_params, *ans)
#      20         return ans
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options)
#      71
#      72     solver = SOLVERS[method](func, y0, rtol=rtol, atol=atol, **options)
# ---> 73     solution = solver.integrate(t)
#      74
#      75     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      29         self.before_integrate(t)
#      30         for i in range(1, len(t)):
# ---> 31             y = self.advance(t[i])
#      32             solution.append(y)
#      33         return tuple(map(torch.stack, tuple(zip(*solution))))
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in advance(self, final_t)
#      95         final_t = _convert_to_tensor(final_t).to(self.vcabm_state.prev_t[0])
#      96         while final_t > self.vcabm_state.prev_t[0]:
# ---> 97             self.vcabm_state = self._adaptive_adams_step(self.vcabm_state, final_t)
#      98         assert final_t == self.vcabm_state.prev_t[0]
#      99         return self.vcabm_state.y_n
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     199
#     200         # perform the step
# --> 201         y1, prev_f, prev_t, next_t, prev_phi, order = super(VariableCoefficientJumpAdamsBashforth, self)._adaptive_adams_step(vcabm_state, final_t)
#     202
#     203         if prev_t[0] == next_t:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     115
#     116         # Update phi to implicit.
# --> 117         next_f0 = self.func(next_t.to(p_next[0]), p_next)
#     118         implicit_phi_p = compute_implicit_phi(phi, next_f0, order + 1)
#     119
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in forward(self, t, y)
#     180
#     181             def forward(self, t, y):
# --> 182                 return (self.func(t, y[0]),)
#     183
#     184
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/module/utils.py in forward(self, t, z)
#     318             dcdt = dcdt - (dcdt*c).sum(dim=-1, keepdim=True) / (c*c).sum(dim=-1, keepdim=True) * c
#     319
# --> 320         dhdt = -self.G(c) * h
#     321
#     322         return torch.cat((dcdt, dhdt), dim=-1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/module/utils.py in forward(self, x)
#     164
#     165     def forward(self, x):
# --> 166         for m in self.linears[:-1]:
#     167             x = self.activation(m(x))
#     168
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in __getitem__(self, idx)
#     291     def __getitem__(self, idx: Union[int, slice]) -> Union[Module, 'ModuleList']:
#     292         if isinstance(idx, slice):
# --> 293             return self.__class__(list(self._modules.values())[idx])
#     294         else:
#     295             return self._modules[self._get_abs_string_index(idx)]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in __init__(self, modules)
#     275
#     276     def __init__(self, modules: Optional[Iterable[Module]] = None) -> None:
# --> 277         super().__init__()
#     278         if modules is not None:
#     279             self += modules
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __init__(self, *args, **kwargs)
#     456         super().__setattr__ for all other attributes.
#     457         """
# --> 458         super().__setattr__('training', True)
#     459         super().__setattr__('_parameters', OrderedDict())
#     460         super().__setattr__('_buffers', OrderedDict())
#
# KeyboardInterrupt:

# %%
# Do the testing separately on the rest of the dataset
# The test loss is calculated on each datapoint separately as batch size = 1
model.predict(data.ts[6000:6005], 1.0 / 30.0)

# %% [markdown]
# # ATM Dataset

# %%
import numpy as np
from module.datasets import ATMDataset

# %%
atm_params = {'seq_len': 10}

train_set = ATMDataset(atm_params, subset='train')
test_set = ATMDataset(atm_params, subset='test')
# Out:
# 100%|██████████| 370102/370102 [00:02<00:00, 145716.43it/s]
# TOTAL SEQs: 360417
# <0.001 = 0.7278214584853152
# <0.01 = 0.8774121207208667
# <0.1 = 0.9104131204236579
# <1 = 0.9390532544378698
# <10 = 0.9831806760152387
# <100 = 0.9999567696090351
# 100%|██████████| 182095/182095 [00:00<00:00, 232909.24it/s]
# TOTAL SEQs: 177914
# <0.001 = 0.7150568634234472
# <0.01 = 0.8972010345793314
# <0.1 = 0.9240045468773167
# <1 = 0.9480623603125704
# <10 = 0.9851347863571714
# <100 = 0.9999450860227453

# %%
train = np.array(train_set)

# %%
train, tspan = ATMDataset.process_njsde(train)

# %%
# This tspan is used for testing the code. Use the actual value when training
tspan = (0.0, 10.0)
len(train), len(train[0]), len(train[0][0]), train[0][0], tspan
# Out:
# (360417, 10, 2, (0.0, 4), (0.0, 10.0))

# %%
from module.config import njsde_params
from module.models import njsde

# %%
njsde_params['num_types'] = 7
njsde_params['niters'] = 11
njsde_params
# Out:
# {'niters': 11,
#  'jump_type': 'read',
#  'batch_size': 1,
#  'nsave': 10,
#  'fold': 0,
#  'num_types': 7,
#  'restart': False,
#  'evnt_align': False,
#  'seed0': False,
#  'debug': False}

# %%
model = njsde(njsde_params)

# %%
model.train(train[:300000], tspan)
# Out:
# iter: 0, current loss:    53.5260, running ave loss:    53.5260, type error: tensor([0.6667])
# iter: 1, current loss:    54.8512, running ave loss:    53.5393, type error: tensor([1.])
# iter: 2, current loss:    53.2805, running ave loss:    53.5367, type error: tensor([1.])
# iter: 3, current loss:    52.4310, running ave loss:    53.5256, type error: tensor([1.])
# iter: 4, current loss:    51.8403, running ave loss:    53.5088, type error: tensor([1.])
# iter: 5, current loss:    50.6249, running ave loss:    53.4800, type error: tensor([1.])
# iter: 6, current loss:    49.3232, running ave loss:    53.4384, type error: tensor([1.])
# iter: 7, current loss:    49.5366, running ave loss:    53.3994, type error: tensor([1.])
# iter: 8, current loss:    48.2307, running ave loss:    53.3477, type error: tensor([1.])
# iter: 9, current loss:    47.3788, running ave loss:    53.2880, type error: tensor([1.])
# validation loss:    44.0208, num_evnts:        1, type error: tensor([1.])
# iter: 10, current loss:    46.2534, running ave loss:    53.2177, type error: tensor([0.2222])
# testing loss:    42.8143, num_evnts:        0, type error: tensor([-1.])
# testing loss:    43.1549, num_evnts:        1, type error: tensor([0.])
# testing loss:    43.1597, num_evnts:        1, type error: tensor([0.])
# testing loss:    42.8143, num_evnts:        0, type error: tensor([-1.])
# testing loss:    43.1501, num_evnts:        1, type error: tensor([0.])
# testing loss:    43.4189, num_evnts:        1, type error: tensor([1.])
# testing loss:    46.7344, num_evnts:        9, type error: tensor([0.5556])
# testing loss:    46.5824, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    46.5250, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    46.0371, num_evnts:        9, type error: tensor([1.])
# testing loss:    46.0369, num_evnts:        9, type error: tensor([1.])
# testing loss:    45.5625, num_evnts:        8, type error: tensor([1.])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-dc27c5348579> in <cell line: 1>()
# ----> 1 model.train(train[:300000], tspan)
#
# /content/module/models.py in train(self, ts, tspan)
#     170
#     171         # computing testing error
# --> 172         self.predict(TSTE, dt)
#     173
#     174     def evaluate(self, TSVA, dt=1.0 / 30.0):
#
# /content/module/models.py in predict(self, TSTE, dt)
#     193     def predict(self, TSTE, dt):
#     194         for si in range(0, len(TSTE), self.params['batch_size']):
# --> 195             tsave, trace, lmbda, gtid, tsne, loss, mete = forward_pass(self.func, torch.cat((self.c0, self.h0), dim=-1),
#     196                                                                        self.tspan, dt,
#     197                                                                        TSTE[si:si + self.params['batch_size']],
#
# /content/module/utils.py in forward_pass(func, z0, tspan, dt, batch, evnt_align, gs_info, type_forecast, predict_first, rtol, atol, scale)
#     487
#     488     # forward pass
# --> 489     trace = odeint(func, z0.repeat(len(batch), 1), tsave, method='jump_adams', rtol=rtol, atol=atol)
#     490     params = func.L(trace)
#     491     lmbda = params[..., :func.dim_N]
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in odeint_adjoint(func, y0, t, rtol, atol, method, options)
#     210
#     211     flat_params = _flatten(func.parameters())
# --> 212     ys = OdeintAdjointMethod.apply(*y0, func, t, flat_params, rtol, atol, method, options)
#     213
#     214     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     504             # See NOTE: [functorch vjp and autograd interaction]
#     505             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     507
#     508         if cls.setup_context == _SingleLevelFunction.setup_context:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in forward(ctx, *args)
#      16
#      17         with torch.no_grad():
# ---> 18             ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options)
#      19         ctx.save_for_backward(t, flat_params, *ans)
#      20         return ans
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options)
#      71
#      72     solver = SOLVERS[method](func, y0, rtol=rtol, atol=atol, **options)
# ---> 73     solution = solver.integrate(t)
#      74
#      75     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      29         self.before_integrate(t)
#      30         for i in range(1, len(t)):
# ---> 31             y = self.advance(t[i])
#      32             solution.append(y)
#      33         return tuple(map(torch.stack, tuple(zip(*solution))))
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in advance(self, final_t)
#      95         final_t = _convert_to_tensor(final_t).to(self.vcabm_state.prev_t[0])
#      96         while final_t > self.vcabm_state.prev_t[0]:
# ---> 97             self.vcabm_state = self._adaptive_adams_step(self.vcabm_state, final_t)
#      98         assert final_t == self.vcabm_state.prev_t[0]
#      99         return self.vcabm_state.y_n
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     199
#     200         # perform the step
# --> 201         y1, prev_f, prev_t, next_t, prev_phi, order = super(VariableCoefficientJumpAdamsBashforth, self)._adaptive_adams_step(vcabm_state, final_t)
#     202
#     203         if prev_t[0] == next_t:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     108         # Explicit predictor step.
#     109         g, phi = g_and_explicit_phi(prev_t, next_t, prev_phi, order)
# --> 110         g = g.to(y0[0])
#     111         p_next = tuple(
#     112             y0_ + _scaled_dot_product(dt_cast, g[:max(1, order - 1)], phi_[:max(1, order - 1)])
#
# KeyboardInterrupt:

# %%
model.predict(train[300000:300005], 1.0/30.0)
# Out:
# testing loss:    45.6262, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    45.6393, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    45.6672, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    45.6070, num_evnts:        9, type error: tensor([0.6667])
# testing loss:    45.6136, num_evnts:        9, type error: tensor([0.6667])

# %% [markdown]
# #Mimic2 Dataset

# %%
from module.datasets import stackOverflow

# %%
data = stackOverflow({}, './mimic/')

# %%
len(data.ts), len(data.ts[0]), len(data.ts[0][0]), data.ts[0][0], data.tspan
# Out:
# (650, 4, 2, (3.858024691358025e-07, 1), (0.0, 3.0419040835707504e-06))

# %%
from module.config import njsde_params

# %%
njsde_params['num_types'] = 75
njsde_params['niters'] = 2
njsde_params
# Out:
# {'niters': 2,
#  'jump_type': 'read',
#  'batch_size': 1,
#  'nsave': 10,
#  'fold': 0,
#  'num_types': 75,
#  'restart': False,
#  'evnt_align': False,
#  'seed0': False,
#  'debug': False}

# %%
from module.models import njsde

# %%
model = njsde(njsde_params)

# %%
model.train(data.ts[:645], data.tspan)
# Out:
# iter: 0, current loss:     3.6370, running ave loss:     3.6370, type error: tensor([1.])
# iter: 1, current loss:     2.6940, running ave loss:     3.6276, type error: tensor([1.])
# testing loss:     3.5378, num_evnts:        4, type error: tensor([1.])
# testing loss:     3.4397, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.8987, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.3178, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.7830, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.0434, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.8649, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.6695, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.9066, num_evnts:        7, type error: tensor([1.])
# testing loss:     2.4069, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.8649, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     4.1769, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.4225, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.6937, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.2945, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.4689, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.7830, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.0222, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.2074, num_evnts:        5, type error: tensor([1.])
# testing loss:     3.4689, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.8649, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.7582, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.2149, num_evnts:        5, type error: tensor([1.])
# testing loss:     9.9464, num_evnts:       17, type error: tensor([1.])
# testing loss:     2.8098, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.7514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.4946, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.4069, num_evnts:        4, type error: tensor([1.])
# testing loss:     3.7978, num_evnts:        7, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9678, num_evnts:        4, type error: tensor([1.])
# testing loss:     3.6364, num_evnts:        5, type error: tensor([1.])
# testing loss:     3.5460, num_evnts:        4, type error: tensor([1.])
# testing loss:     5.7507, num_evnts:       11, type error: tensor([1.])
# testing loss:     2.4069, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.4255, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.4841, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.5816, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.5027, num_evnts:        6, type error: tensor([1.])
# testing loss:     3.4689, num_evnts:        4, type error: tensor([1.])
# testing loss:     3.2522, num_evnts:        3, type error: tensor([1.])
# testing loss:     5.2767, num_evnts:       12, type error: tensor([1.])
# testing loss:     2.5816, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9678, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.5777, num_evnts:        6, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.1398, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.4760, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.1045, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.0222, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.1334, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.0222, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.6096, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.2385, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.1967, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.4260, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.2469, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     6.1893, num_evnts:       10, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     7.3676, num_evnts:       19, type error: tensor([1.])
# testing loss:     3.6962, num_evnts:        5, type error: tensor([1.])
# testing loss:     3.0222, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9158, num_evnts:        4, type error: tensor([1.])
# testing loss:     4.2384, num_evnts:        7, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.7514, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.2074, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.6571, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9701, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.2864, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.7514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.3374, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.4317, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.2074, num_evnts:        5, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.3786, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.9119, num_evnts:        4, type error: tensor([1.])
# testing loss:     2.3374, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.5491, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6155, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.6514, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.5027, num_evnts:        6, type error: tensor([1.])

# %%
model.predict(data.ts[645:], 1.0/30.0)
# Out:
# testing loss:     2.8601, num_evnts:        3, type error: tensor([1.])
# testing loss:     2.3743, num_evnts:        2, type error: tensor([1.])
# testing loss:     2.4760, num_evnts:        2, type error: tensor([1.])
# testing loss:     3.0986, num_evnts:        3, type error: tensor([1.])
# testing loss:     3.1468, num_evnts:        4, type error: tensor([1.])

# %% [markdown]
# #Pilot Elevator Dataset

# %%
from module.datasets import nhpDatareader
from module.config import nhp_dataset_params

# %%
#nhp_dataset_params = {'PathData':'./data/'}
nhp_dataset_params
# Out:
# {'PathData': './data/'}

# %%
nhp_data = nhpDatareader(nhp_dataset_params)

# %%
train_data, val_data, total_event_num = nhp_data.read_data()

# %%
train, tspan = nhp_data.process_njsde()
tspan = (0.0, 10)

# %%
len(train), len(train[0]), len(train[0][0]), train[0][0], tspan
# Out:
# (1000, 326, 2, (18.794584274291992, 7), (0.0, 10))

# %%
from module.config import njsde_params

# %%
njsde_params['niters'] = 2
njsde_params['num_types'] = 11
njsde_params
# Out:
# {'niters': 2,
#  'jump_type': 'read',
#  'batch_size': 1,
#  'nsave': 10,
#  'fold': 0,
#  'num_types': 11,
#  'restart': False,
#  'evnt_align': False,
#  'seed0': False,
#  'debug': False}

# %%
from module.models import njsde

# %%
model = njsde(njsde_params)

# %%
## Each epoch time = 1hr 5min
model.train(train[:995], tspan)
# Out:
# iter: 0, current loss:    75.8054, running ave loss:    75.8054, type error: tensor([-1.])
# iter: 1, current loss:    74.3447, running ave loss:    75.7908, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.8957, num_evnts:        0, type error: tensor([-1.])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-f398ef0e36af> in <cell line: 2>()
#       1 ## Each epoch time = 1hr 5min
# ----> 2 model.train(train[:995], tspan)
#
# /content/module/models.py in train(self, ts, tspan)
#     170
#     171         # computing testing error
# --> 172         self.predict(TSTE, dt)
#     173
#     174     def evaluate(self, TSVA, dt=1.0 / 30.0):
#
# /content/module/models.py in predict(self, TSTE, dt)
#     193     def predict(self, TSTE, dt):
#     194         for si in range(0, len(TSTE), self.params['batch_size']):
# --> 195             tsave, trace, lmbda, gtid, tsne, loss, mete = forward_pass(self.func, torch.cat((self.c0, self.h0), dim=-1),
#     196                                                                        self.tspan, dt,
#     197                                                                        TSTE[si:si + self.params['batch_size']],
#
# /content/module/utils.py in forward_pass(func, z0, tspan, dt, batch, evnt_align, gs_info, type_forecast, predict_first, rtol, atol, scale)
#     487
#     488     # forward pass
# --> 489     trace = odeint(func, z0.repeat(len(batch), 1), tsave, method='jump_adams', rtol=rtol, atol=atol)
#     490     params = func.L(trace)
#     491     lmbda = params[..., :func.dim_N]
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in odeint_adjoint(func, y0, t, rtol, atol, method, options)
#     210
#     211     flat_params = _flatten(func.parameters())
# --> 212     ys = OdeintAdjointMethod.apply(*y0, func, t, flat_params, rtol, atol, method, options)
#     213
#     214     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     504             # See NOTE: [functorch vjp and autograd interaction]
#     505             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     507
#     508         if cls.setup_context == _SingleLevelFunction.setup_context:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in forward(ctx, *args)
#      16
#      17         with torch.no_grad():
# ---> 18             ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options)
#      19         ctx.save_for_backward(t, flat_params, *ans)
#      20         return ans
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options)
#      71
#      72     solver = SOLVERS[method](func, y0, rtol=rtol, atol=atol, **options)
# ---> 73     solution = solver.integrate(t)
#      74
#      75     if tensor_input:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      29         self.before_integrate(t)
#      30         for i in range(1, len(t)):
# ---> 31             y = self.advance(t[i])
#      32             solution.append(y)
#      33         return tuple(map(torch.stack, tuple(zip(*solution))))
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in advance(self, final_t)
#      95         final_t = _convert_to_tensor(final_t).to(self.vcabm_state.prev_t[0])
#      96         while final_t > self.vcabm_state.prev_t[0]:
# ---> 97             self.vcabm_state = self._adaptive_adams_step(self.vcabm_state, final_t)
#      98         assert final_t == self.vcabm_state.prev_t[0]
#      99         return self.vcabm_state.y_n
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     199
#     200         # perform the step
# --> 201         y1, prev_f, prev_t, next_t, prev_phi, order = super(VariableCoefficientJumpAdamsBashforth, self)._adaptive_adams_step(vcabm_state, final_t)
#     202
#     203         if prev_t[0] == next_t:
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adams.py in _adaptive_adams_step(self, vcabm_state, final_t)
#     115
#     116         # Update phi to implicit.
# --> 117         next_f0 = self.func(next_t.to(p_next[0]), p_next)
#     118         implicit_phi_p = compute_implicit_phi(phi, next_f0, order + 1)
#     119
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/adjoint.py in forward(self, t, y)
#     180
#     181             def forward(self, t, y):
# --> 182                 return (self.func(t, y[0]),)
#     183
#     184
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/module/utils.py in forward(self, t, z)
#     318             dcdt = dcdt - (dcdt*c).sum(dim=-1, keepdim=True) / (c*c).sum(dim=-1, keepdim=True) * c
#     319
# --> 320         dhdt = -self.G(c) * h
#     321
#     322         return torch.cat((dcdt, dhdt), dim=-1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/module/utils.py in forward(self, x)
#     165     def forward(self, x):
#     166         for m in self.linears[:-1]:
# --> 167             x = self.activation(m(x))
#     168
#     169         return self.linears[-1](x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     111             init.uniform_(self.bias, -bound, bound)
#     112
# --> 113     def forward(self, input: Tensor) -> Tensor:
#     114         return F.linear(input, self.weight, self.bias)
#     115
#
# KeyboardInterrupt:

# %%
model.predict(train[995:], 1.0/30.0)
# Out:
# testing loss:    72.5498, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.5498, num_evnts:        0, type error: tensor([-1.])
# testing loss:    72.5498, num_evnts:        0, type error: tensor([-1.])
# testing loss:    73.2266, num_evnts:        1, type error: tensor([1.])
# testing loss:    72.5498, num_evnts:        0, type error: tensor([-1.])
